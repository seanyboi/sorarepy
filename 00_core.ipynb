# %%
# default_exp core

# %% [markdown]
# # module name here
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
say_hello("sean")
# Out:
# 'Hello sean!'
